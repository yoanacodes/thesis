# %%
import pandas as pd
import numpy as np

# %%
df_codes = pd.read_csv('data/nutrition_codes.csv')
df_codes.head()
# Out:
#   Numeric Code        GDD Variable Label
# 0          v01                    Fruits
# 1          v02    Non-starchy vegetables
# 2          v03                  Potatoes
# 3          v04  Other starchy vegetables
# 4          v05         Beans and legumes

# %%
df_codes.rename({'GDD Variable Label': 'label', 'Numeric Code': 'value'}, axis=1, inplace=True)
df_codes.head()
# Out:
#   value                     label
# 0   v01                    Fruits
# 1   v02    Non-starchy vegetables
# 2   v03                  Potatoes
# 3   v04  Other starchy vegetables
# 4   v05         Beans and legumes

# %%
df_codes
# Out:
#    value                               label
# 0    v01                              Fruits
# 1    v02              Non-starchy vegetables
# 2    v03                            Potatoes
# 3    v04            Other starchy vegetables
# 4    v05                   Beans and legumes
# 5    v06                      Nuts and seeds
# 6    v07                      Refined grains
# 7    v08                        Whole grains
# 8    v09               Total processed meats
# 9    v10               Unprocessed red meats
# 10   v11                      Total seafoods
# 11   v12                                Eggs
# 12   v13                              Cheese
# 13   v14  Yoghurt (including fermented milk)
# 14   v15           Sugar-sweetened beverages
# 15   v16                        Fruit juices
# 16   v17                              Coffee
# 17   v18                                 Tea
# 18   v22                 Total carbohydrates
# 19   v23                       Total protein
# 20   v27                       Saturated fat
# 21   v28         Monounsaturated fatty acids
# 22   v29                   Total omega-6 fat
# 23   v30                 Seafood omega-3 fat
# 24   v31                   Plant omega-3 fat
# 25   v33                 Dietary cholesterol
# 26   v34                       Dietary fiber
# 27   v35                        Added sugars
# 28   v36                             Calcium
# 29   v37                      Dietary sodium
# 30   v38                              Iodine
# 31   v39                                Iron
# 32   v40                           Magnesium
# 33   v41                           Potassium
# 34   v42                            Selenium
# 35   v43            Vitamin A w/ supplements
# 36   v45                          Vitamin B1
# 37   v46                          Vitamin B2
# 38   v47                          Vitamin B3
# 39   v48                          Vitamin B6
# 40   v49                 Vitamin B9 (Folate)
# 41   v50                         Vitamin B12
# 42   v51                           Vitamin C
# 43   v52                           Vitamin D
# 44   v53                           Vitamin E
# 45   v54                                Zinc
# 46   v57                          Total Milk

# %%
df_codes['label'].unique()
# Out:
# array(['Fruits', 'Non-starchy vegetables', 'Potatoes',
#        'Other starchy vegetables', 'Beans and legumes', 'Nuts and seeds',
#        'Refined grains', 'Whole grains', 'Total processed meats',
#        'Unprocessed red meats', 'Total seafoods', 'Eggs', 'Cheese',
#        'Yoghurt (including fermented milk)', 'Sugar-sweetened beverages',
#        'Fruit juices', 'Coffee', 'Tea', 'Total carbohydrates',
#        'Total protein', 'Saturated fat', 'Monounsaturated fatty acids',
#        'Total omega-6 fat', 'Seafood omega-3 fat', 'Plant omega-3 fat',
#        'Dietary cholesterol', 'Dietary fiber', 'Added sugars', 'Calcium',
#        'Dietary sodium', 'Iodine', 'Iron', 'Magnesium', 'Potassium',
#        'Selenium', 'Vitamin A w/ supplements', 'Vitamin B1', 'Vitamin B2',
#        'Vitamin B3', 'Vitamin B6', 'Vitamin B9 (Folate)', 'Vitamin B12',
#        'Vitamin C', 'Vitamin D', 'Vitamin E', 'Zinc', 'Total Milk'],
#       dtype=object)

# %%
df_codes['label'].nunique()
# Out:
# 47

# %%
df_serving_size = pd.read_csv('data/nutrition_serving_sizes.csv')
df_serving_size.head()
# Out:
#   GDD Variable Label                              GDD Variable Unit
# 0       Added sugars  % of total kcal per day (energy contribution)
# 1  Beans and legumes                                  grams per day
# 2            Calcium                        milligrams (mg) per day
# 3             Cheese                                  grams per day
# 4             Coffee                          cups/day (1 cup=8 oz)

# %%
df_serving_size.rename({'GDD Variable Label': 'label', 'GDD Variable Unit': 'serving_size'}, axis=1, inplace=True)
df_serving_size.head()
# Out:
#                label                                   serving_size
# 0       Added sugars  % of total kcal per day (energy contribution)
# 1  Beans and legumes                                  grams per day
# 2            Calcium                        milligrams (mg) per day
# 3             Cheese                                  grams per day
# 4             Coffee                          cups/day (1 cup=8 oz)

# %%
df_serving_size['label'].unique()
# Out:
# array(['Added sugars', 'Beans and legumes', 'Calcium', 'Cheese', 'Coffee',
#        'Dietary cholesterol', 'Dietary fiber', 'Dietary sodium', 'Eggs',
#        'Fruit juices', 'Fruits', 'Iodine', 'Iron', 'Magnesium',
#        'Monounsaturated fat', 'Non-starchy vegetables', 'Nuts and seeds',
#        'Other starchy vegetables', 'Plant omega-3 (n-3) fat',
#        'Plant protein', 'Potassium', 'Potatoes', 'Reduced fat milk',
#        'Refined grains', 'Saturated fat', 'Seafood omega-3 (n-3) fat',
#        'Selenium', 'Sugar-sweetened beverages', 'Tea',
#        'Total animal protein', 'Total carbohydrates', 'Total energy',
#        'Total Milk', 'Total omega-6 fatty acids', 'Total processed meats',
#        'Total protein', 'Total seafoods', 'Unprocessed red meats',
#        'Vitamin A with supplements', 'Vitamin A without supplements',
#        'Vitamin B1', 'Vitamin B12', 'Vitamin B2', 'Vitamin B3',
#        'Vitamin B6', 'Vitamin B9 (Folate)', 'Vitamin C', 'Vitamin D',
#        'Vitamin E', 'Whole fat milk', 'Whole grains',
#        'Yoghurt (including fermented milk)', 'Zinc'], dtype=object)

# %%
df_serving_size['label'].nunique()
# Out:
# 53

# %% [markdown]
# ##### Find differences in the variable names between the two datasets

# %%
# get unique foods in both datasets
unique_codes_list = df_codes['label'].unique()
print('\nUnique unique_codes_list:', len(unique_codes_list))
unique_serving_sizes = df_serving_size['label'].unique()
print('Unique unique_serving_sizes:', len(unique_serving_sizes))

# find the foods not in df_codes
difference_1 = list(set(unique_serving_sizes) - set(unique_codes_list))
print('\nfoods not in df_codes', len(difference_1), ':', difference_1)

# find the foods not in df_serving_size
difference_2 = list(set(unique_codes_list) - set(unique_serving_sizes))
print('\nfoods not in df_serving_size', len(difference_2), ':', difference_2)
# Out:
# Unique unique_codes_list: 47
# Unique unique_serving_sizes: 53
#
# foods not in df_codes 11 : ['Vitamin A without supplements', 'Whole fat milk', 'Seafood omega-3 (n-3) fat', 'Plant protein', 'Monounsaturated fat', 'Vitamin A with supplements', 'Plant omega-3 (n-3) fat', 'Total omega-6 fatty acids', 'Reduced fat milk', 'Total energy', 'Total animal protein']
#
# foods not in df_serving_size 5 : ['Seafood omega-3 fat', 'Vitamin A w/ supplements', 'Monounsaturated fatty acids', 'Total omega-6 fat', 'Plant omega-3 fat']

# %%
print('Total omega-6 fatty acids' in df_codes['label'].values)
# Out:
# False

# %% [markdown]
# ##### Create dictionary to fix differences in variable labels

# %%
values_names = [
    {
        "code": "Total omega-6 fatty acids",
        "serving": "Total omega-6 fat"
    },
    {
        "code": "Plant omega-3 (n-3) fat",
        "serving": "Plant omega-3 fat"
    },
    {
        "code": "Vitamin A without supplements",
        "serving": "Vitamin A w/ supplements"
    },
    {
        "code": "Seafood omega-3 (n-3) fat",
        "serving": "Seafood omega-3 fat"
    },
    {
        "code": "Monounsaturated fat",
        "serving": "Monounsaturated fatty acids"
    }
]

# %% [markdown]
# ##### Reassing names in the df_serving_size dataframe

# %%
for name in values_names:
  df_serving_size['label'] = np.where(df_serving_size['label'] == name['serving'], name['code'], df_serving_size['label'])

df_serving_size.head()
# Out:
#                label                                   serving_size
# 0       Added sugars  % of total kcal per day (energy contribution)
# 1  Beans and legumes                                  grams per day
# 2            Calcium                        milligrams (mg) per day
# 3             Cheese                                  grams per day
# 4             Coffee                          cups/day (1 cup=8 oz)

# %% [markdown]
# ### Merge datasets

# %%
data = pd.merge(df_codes, df_serving_size, on="label")

# %%
data
# Out:
#    value                               label  \
# 0    v01                              Fruits
# 1    v02              Non-starchy vegetables
# 2    v03                            Potatoes
# 3    v04            Other starchy vegetables
# 4    v05                   Beans and legumes
# 5    v06                      Nuts and seeds
# 6    v07                      Refined grains
# 7    v08                        Whole grains
# 8    v09               Total processed meats
# 9    v10               Unprocessed red meats
# 10   v11                      Total seafoods
# 11   v12                                Eggs
# 12   v13                              Cheese
# 13   v14  Yoghurt (including fermented milk)
# 14   v15           Sugar-sweetened beverages
# 15   v16                        Fruit juices
# 16   v17                              Coffee
# 17   v18                                 Tea
# 18   v22                 Total carbohydrates
# 19   v23                       Total protein
# 20   v27                       Saturated fat
# 21   v33                 Dietary cholesterol
# 22   v34                       Dietary fiber
# 23   v35                        Added sugars
# 24   v36                             Calcium
# 25   v37                      Dietary sodium
# 26   v38                              Iodine
# 27   v39                                Iron
# 28   v40                           Magnesium
# 29   v41                           Potassium
# 30   v42                            Selenium
# 31   v45                          Vitamin B1
# 32   v46                          Vitamin B2
# 33   v47                          Vitamin B3
# 34   v48                          Vitamin B6
# 35   v49                 Vitamin B9 (Folate)
# 36   v50                         Vitamin B12
# 37   v51                           Vitamin C
# 38   v52                           Vitamin D
# 39   v53                           Vitamin E
# 40   v54                                Zinc
# 41   v57                          Total Milk
#
#                                      serving_size
# 0                                   grams per day
# 1                                   grams per day
# 2                                   grams per day
# 3                                   grams per day
# 4                                   grams per day
# 5                                   grams per day
# 6                                   grams per day
# 7                                   grams per day
# 8                                   grams per day
# 9                                   grams per day
# 10                                  grams per day
# 11                                  grams per day
# 12                                  grams per day
# 13                                  grams per day
# 14                                  grams per day
# 15                                  grams per day
# 16                          cups/day (1 cup=8 oz)
# 17                          cups/day (1 cup=8 oz)
# 18  % of total kcal per day (energy contribution)
# 19                                  grams per day
# 20  % of total kcal per day (energy contribution)
# 21                        milligrams (mg) per day
# 22                                  grams per day
# 23  % of total kcal per day (energy contribution)
# 24                        milligrams (mg) per day
# 25                        milligrams (mg) per day
# 26                        micrograms (µg) per day
# 27                        milligrams (mg) per day
# 28                        milligrams (mg) per day
# 29                        milligrams (mg) per day
# 30                        micrograms (µg) per day
# 31                        milligrams (mg) per day
# 32                        milligrams (mg) per day
# 33                        milligrams (mg) per day
# 34                        milligrams (mg) per day
# 35                    micrograms (µg) per day DFE
# 36                        micrograms (µg) per day
# 37                        milligrams (mg) per day
# 38                        micrograms (µg) per day
# 39                        milligrams (mg) per day
# 40                        milligrams (mg) per day
# 41                                  grams per day

# %%
food_groups = [
    {
        "category": "Foods",
        "values": ['Fruits', 'Non-starchy vegetables', 'Potatoes', 'Other starchy vegetables', 'Beans and legumes', 
                   'Nuts and seeds', 'Refined grains', 'Whole grains', 'Unprocessed red meats', 'Total processed meats', 
                  'Total seafoods', 'Eggs', 'Cheese', 'Yoghurt (including fermented milk)']
    }, 
    {
        "category": "Beverages",
        "values": ['Sugar-sweetened beverages', 'Fruit juices', 'Coffee', 'Tea', 'Whole Fat Milk', 'Reduced Fat Milk',
                  'Total Milk']
    },
    {
        "category": "Macronutrients",
        "values": ['Total carbohydrates', 'Total protein', 'Total Animal Protein', 'Plant Protein', 'Saturated fat', 
                  'Monounsaturated Fat', 'Total Omega-6 Fatty Acids', 'Seafood Omega-3 Fatty Acids', 'Plant Omega-3 Fatty Acids',
                  'Dietary cholesterol', 'Dietary fiber', 'Added sugars']
    },
    {
        "category": "Micronutrients",
        "values": ['Calcium', 'Dietary sodium', 'Iodine', 'Iron', 'Magnesium', 'Potassium', 'Selenium', 
                   'Vitamin A w/ supplements', 'Vitamin B1', 'Vitamin B2', 'Vitamin B3', 'Vitamin B6', 'Vitamin B9 (Folate)',
                  'Vitamin B12', 'Vitamin C', 'Vitamin D', 'Vitamin E', 'Zinc']
    }
]

# %%
data.head()
data['food_group'] = ''
data.head()
# Out:
#   value                     label   serving_size food_group
# 0   v01                    Fruits  grams per day
# 1   v02    Non-starchy vegetables  grams per day
# 2   v03                  Potatoes  grams per day
# 3   v04  Other starchy vegetables  grams per day
# 4   v05         Beans and legumes  grams per day

# %%
for group in food_groups:
#     print(group['category'], group['values'])
    for index, row in data.iterrows():
#         print(row['label'])
        if row['label'] in group['values']:
            row['food_group'] = group['category']
#     for nutrient in group['values']:
#         print(nutrient)
data
# Out:
#    value                               label  \
# 0    v01                              Fruits
# 1    v02              Non-starchy vegetables
# 2    v03                            Potatoes
# 3    v04            Other starchy vegetables
# 4    v05                   Beans and legumes
# 5    v06                      Nuts and seeds
# 6    v07                      Refined grains
# 7    v08                        Whole grains
# 8    v09               Total processed meats
# 9    v10               Unprocessed red meats
# 10   v11                      Total seafoods
# 11   v12                                Eggs
# 12   v13                              Cheese
# 13   v14  Yoghurt (including fermented milk)
# 14   v15           Sugar-sweetened beverages
# 15   v16                        Fruit juices
# 16   v17                              Coffee
# 17   v18                                 Tea
# 18   v22                 Total carbohydrates
# 19   v23                       Total protein
# 20   v27                       Saturated fat
# 21   v33                 Dietary cholesterol
# 22   v34                       Dietary fiber
# 23   v35                        Added sugars
# 24   v36                             Calcium
# 25   v37                      Dietary sodium
# 26   v38                              Iodine
# 27   v39                                Iron
# 28   v40                           Magnesium
# 29   v41                           Potassium
# 30   v42                            Selenium
# 31   v45                          Vitamin B1
# 32   v46                          Vitamin B2
# 33   v47                          Vitamin B3
# 34   v48                          Vitamin B6
# 35   v49                 Vitamin B9 (Folate)
# 36   v50                         Vitamin B12
# 37   v51                           Vitamin C
# 38   v52                           Vitamin D
# 39   v53                           Vitamin E
# 40   v54                                Zinc
# 41   v57                          Total Milk
#
#                                      serving_size      food_group
# 0                                   grams per day           Foods
# 1                                   grams per day           Foods
# 2                                   grams per day           Foods
# 3                                   grams per day           Foods
# 4                                   grams per day           Foods
# 5                                   grams per day           Foods
# 6                                   grams per day           Foods
# 7                                   grams per day           Foods
# 8                                   grams per day           Foods
# 9                                   grams per day           Foods
# 10                                  grams per day           Foods
# 11                                  grams per day           Foods
# 12                                  grams per day           Foods
# 13                                  grams per day           Foods
# 14                                  grams per day       Beverages
# 15                                  grams per day       Beverages
# 16                          cups/day (1 cup=8 oz)       Beverages
# 17                          cups/day (1 cup=8 oz)       Beverages
# 18  % of total kcal per day (energy contribution)  Macronutrients
# 19                                  grams per day  Macronutrients
# 20  % of total kcal per day (energy contribution)  Macronutrients
# 21                        milligrams (mg) per day  Macronutrients
# 22                                  grams per day  Macronutrients
# 23  % of total kcal per day (energy contribution)  Macronutrients
# 24                        milligrams (mg) per day  Micronutrients
# 25                        milligrams (mg) per day  Micronutrients
# 26                        micrograms (µg) per day  Micronutrients
# 27                        milligrams (mg) per day  Micronutrients
# 28                        milligrams (mg) per day  Micronutrients
# 29                        milligrams (mg) per day  Micronutrients
# 30                        micrograms (µg) per day  Micronutrients
# 31                        milligrams (mg) per day  Micronutrients
# 32                        milligrams (mg) per day  Micronutrients
# 33                        milligrams (mg) per day  Micronutrients
# 34                        milligrams (mg) per day  Micronutrients
# 35                    micrograms (µg) per day DFE  Micronutrients
# 36                        micrograms (µg) per day  Micronutrients
# 37                        milligrams (mg) per day  Micronutrients
# 38                        micrograms (µg) per day  Micronutrients
# 39                        milligrams (mg) per day  Micronutrients
# 40                        milligrams (mg) per day  Micronutrients
# 41                                  grams per day       Beverages

# %%
for index, row in data.iterrows():
    row['value'] = row['value'].replace('v', '')
    
data['value'] = data['value'].astype(int)

# %%
data
# Out:
#     value                               label  \
# 0       1                              Fruits
# 1       2              Non-starchy vegetables
# 2       3                            Potatoes
# 3       4            Other starchy vegetables
# 4       5                   Beans and legumes
# 5       6                      Nuts and seeds
# 6       7                      Refined grains
# 7       8                        Whole grains
# 8       9               Total processed meats
# 9      10               Unprocessed red meats
# 10     11                      Total seafoods
# 11     12                                Eggs
# 12     13                              Cheese
# 13     14  Yoghurt (including fermented milk)
# 14     15           Sugar-sweetened beverages
# 15     16                        Fruit juices
# 16     17                              Coffee
# 17     18                                 Tea
# 18     22                 Total carbohydrates
# 19     23                       Total protein
# 20     27                       Saturated fat
# 21     33                 Dietary cholesterol
# 22     34                       Dietary fiber
# 23     35                        Added sugars
# 24     36                             Calcium
# 25     37                      Dietary sodium
# 26     38                              Iodine
# 27     39                                Iron
# 28     40                           Magnesium
# 29     41                           Potassium
# 30     42                            Selenium
# 31     45                          Vitamin B1
# 32     46                          Vitamin B2
# 33     47                          Vitamin B3
# 34     48                          Vitamin B6
# 35     49                 Vitamin B9 (Folate)
# 36     50                         Vitamin B12
# 37     51                           Vitamin C
# 38     52                           Vitamin D
# 39     53                           Vitamin E
# 40     54                                Zinc
# 41     57                          Total Milk
#
#                                      serving_size      food_group
# 0                                   grams per day           Foods
# 1                                   grams per day           Foods
# 2                                   grams per day           Foods
# 3                                   grams per day           Foods
# 4                                   grams per day           Foods
# 5                                   grams per day           Foods
# 6                                   grams per day           Foods
# 7                                   grams per day           Foods
# 8                                   grams per day           Foods
# 9                                   grams per day           Foods
# 10                                  grams per day           Foods
# 11                                  grams per day           Foods
# 12                                  grams per day           Foods
# 13                                  grams per day           Foods
# 14                                  grams per day       Beverages
# 15                                  grams per day       Beverages
# 16                          cups/day (1 cup=8 oz)       Beverages
# 17                          cups/day (1 cup=8 oz)       Beverages
# 18  % of total kcal per day (energy contribution)  Macronutrients
# 19                                  grams per day  Macronutrients
# 20  % of total kcal per day (energy contribution)  Macronutrients
# 21                        milligrams (mg) per day  Macronutrients
# 22                                  grams per day  Macronutrients
# 23  % of total kcal per day (energy contribution)  Macronutrients
# 24                        milligrams (mg) per day  Micronutrients
# 25                        milligrams (mg) per day  Micronutrients
# 26                        micrograms (µg) per day  Micronutrients
# 27                        milligrams (mg) per day  Micronutrients
# 28                        milligrams (mg) per day  Micronutrients
# 29                        milligrams (mg) per day  Micronutrients
# 30                        micrograms (µg) per day  Micronutrients
# 31                        milligrams (mg) per day  Micronutrients
# 32                        milligrams (mg) per day  Micronutrients
# 33                        milligrams (mg) per day  Micronutrients
# 34                        milligrams (mg) per day  Micronutrients
# 35                    micrograms (µg) per day DFE  Micronutrients
# 36                        micrograms (µg) per day  Micronutrients
# 37                        milligrams (mg) per day  Micronutrients
# 38                        micrograms (µg) per day  Micronutrients
# 39                        milligrams (mg) per day  Micronutrients
# 40                        milligrams (mg) per day  Micronutrients
# 41                                  grams per day       Beverages

# %%
data.shape
# Out:
# (42, 4)

# %%
# save as json
# data.to_json('final_datasets/nutrition_filters.json', orient="records")
